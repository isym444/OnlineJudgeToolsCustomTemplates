# %% [markdown]
# ```cpp
#
# using namespace atcoder;
#
# ll op(ll a, ll b)
# {
#   return (a + b);
# }
#
# ll e()
# {
#   return (ll)(0);
# }
#
# ll target;
#
# bool f(ll v) { return v <= target; } // this will be upperbound, for lowerbound do v<target
#
#     segtree<ll, op, e> seg(N);
#     target = t;
#     cur = seg.max_right<f>(0); // 0 is value from which to start binary search
#     /* Starting from non-zero l is legitimately useful for things like: "find the next alive book after position k", which would be seg.max_right<f>(k) with f(v) = v < 1 */
# ```
