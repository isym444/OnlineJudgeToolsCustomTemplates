# %% [markdown]
# ````cpp
# tuple<ll, ll, ll> maxSubarraySum(vector<ll> &arr)
# {
#
#   // Stores the result (maximum sum found so far)
#   ll res = arr[0];
#
#   // Maximum sum of subarray ending at current position
#   ll maxEnding = arr[0];
#
#   ll L = 0;
#   ll R = 0;
#   ll finL = 0;
#   ll finR = 0;
#   for (ll i = 1; i < arr.size(); i++)
#   {
#
#     // Either extend the previous subarray or start
#     // new from current element
#     if (maxEnding + arr[i] > arr[i])
#     {
#       R = i;
#     }
#     else
#     {
#       L = i;
#       R = i;
#     }
#     maxEnding = max(arr[i], maxEnding + arr[i]);
#
#     // Update result if the new subarray sum is larger
#     if (maxEnding > res)
#     {
#       finL = L;
#       finR = R;
#     }
#     res = max(res, maxEnding);
#   }
#   return mt(res, finL, finR);
# }
#
# int main()
# {
#   nyan;
#   ll N, K;
#   cin >> N >> K;
#   vll difs(N);
#   ll ans = 0;
#   foi(0, N)
#   {
#     ll a, b;
#     cin >> a >> b;
#     ans += a;
#     difs[i] = b - a;
#   }
#
#   foi(0, K)
#   {
#     auto [aa, bb, cc] = maxSubarraySum(difs);
#     if (aa > 0)
#     {
#       ans += aa;
#       foj(bb, cc + 1)
#       {
#         difs[j] *= -1;
#       }
#     }
#   }
#   cout << ans << endl;
# }
# ````
