# %% [markdown]
# ````cpp
# #include <atcoder/string>
# using namespace atcoder;
#
# string ts = t + s;                    // Put T first so we can detect T in S
# vector<int> z = z_algorithm(ts);      // Compute Z array
#
# int idx = m;  // Start at position M (where S actually starts in "TS")
#
# while (idx < n + m) {
#     if (z[idx] >= m) {                // Do the next M chars match T?
#         ans++;                        // Yes! Found a match
#         idx += m;                     // Skip past this M-length match
#     } else {                          // No match
#         idx++;                        // Move forward by 1
#     }
# }
# ````

# %% [markdown]
# ![Drawing.png](attachment:Drawing.png)
